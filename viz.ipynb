# %%
from COSMOtherm.src.COSMOtherm_functions.Outputfile_Ingestion import list_files_with_extension, get_output_df
from COSMOtherm.Configfiles import COSMOthermConfig as COSMOConfig
from COSMOtherm.Configfiles import Config
from COSMOtherm.src.funcs import load_and_sort_solvents #build_design_matrix_fullfactorial
from COSMOtherm.src.Design_Matrix import build_design_matrix

solvents = load_and_sort_solvents(Config.solvents_fullpath)
path = "./COSMOtherm/outputfiles/CompleteScreening/"
filelist = list_files_with_extension(folder_path=path, file_extension="tab")
# Out:
# c:\Users\kabe02-lokal\Documents\Github\BayesianThompsonSamplingOptimization\COSMOtherm\src\funcs.py:51: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   solvents = pd.read_csv(solvents_fullpath, delim_whitespace=True)

# %%
filelist
# Out:
# ['./COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1,2-dichloroethane_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-butanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-decanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-heptanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-hexanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-nonanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-octanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_1-undecanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-decanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-heptanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-hexanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-nonanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-octanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_2-undecanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_3-decanone_tc40_x0.021340983896365212.tab',
# ...
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_4-octanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanol_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_5-nonanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_benzene_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_butanone_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ccl4_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc30_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_ch2cl2_tc40_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc20_x0.05930416628155502.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.0010032800176357408.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.0020128913383111492.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.004051349137288097.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.010325086834736085.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.021340983896365212.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.03311941974040262.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.04574240928256.tab',
#  './COSMOtherm/outputfiles/CompleteScreening\\LIQEX_chcl3_tc30_x0.05930416628155502.tab',
#  ...]

# %%
output_data = get_output_df(files=filelist)


solvents["index"] = solvents.index

output_data = output_data.merge(solvents[['COSMO_name','index']], left_on='Compound 2', right_on='COSMO_name', how='left')

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Extract unique ranges
temperature_range = output_data['Temperature (°C)'].unique().tolist()
lactic_acid_range = output_data["Phase 1 x(3) input"].unique().tolist()
solvent_indices = output_data.sort_values(by=["index"])["index"].unique().tolist()

print(f"Temperature range: {temperature_range}")
print(f"Lactic acid range: {lactic_acid_range}")

# Create a list of DataFrames for each lactic acid value
data_by_lactic_acid = []
for la_val in lactic_acid_range:
    filtered_data = output_data[output_data["Phase 1 x(3) input"] == la_val]
    filtered_data = filtered_data.sort_values(by=["index", "Temperature (°C)"]).reset_index(drop=True)
    data_by_lactic_acid.append(filtered_data)


# Create a meshgrid for temperature and solvent indices
temperature = np.array(temperature_range)
solvent_indices_array = np.array(solvent_indices)
X, Y = np.meshgrid(temperature, solvent_indices_array)

# Prepare Z values (Phase 2 x(3) output / Phase 1 x(3) output)
KV_values = []
x_la_org_values = []
for la_value in lactic_acid_range:
    x_la_org = np.zeros_like(X, dtype=float)
    KV = np.zeros_like(X, dtype=float)
    for i, temp in enumerate(temperature):
        for j, solvent_idx in enumerate(solvent_indices):
            filtered_data = output_data[(output_data["index"] == solvent_idx) & (output_data["Temperature (°C)"] == temp) & (output_data["Phase 1 x(3) input"] == la_value)]
            if not filtered_data.empty:
                x_la_org[j, i] = filtered_data["Phase 2 x(3) output"].values[0] / filtered_data["Phase 1 x(3) output"].values[0]
                KV[j, i] = filtered_data["Phase 2 x(3) output"].values[0]
    x_la_org_values.append(x_la_org)
    KV_values.append(KV)
# Out:
# Temperature range: [20.0, 30.0, 40.0]
# Lactic acid range: [0.0010033, 0.0020129, 0.0040513, 0.0103, 0.0213, 0.0331, 0.0457, 0.0593]

# %%
# %matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Adjust the figure size to stretch in the y-direction
fig = plt.figure(figsize=(12, 16))  # Increase the height to stretch the plot
ax = fig.add_subplot(111, projection='3d')

# Keep the axis projection as is
# ax.get_proj = lambda: np.dot(Axes3D.get_proj(ax), np.diag([1, 2, 1, 1]))

ax.set_box_aspect([0.25, 1, 0.25])  # Equal aspect ratio for x, y, z

# Plot the surface
surf_1 = ax.plot_surface(X, Y, KV_values[0], cmap='viridis', edgecolor='k', alpha=0.8)
surf_2 = ax.plot_surface(X, Y, KV_values[-1], cmap='viridis', edgecolor='k', alpha=0.8)

# Replace solvent indices with COSMO_name values for y-axis labels
y_labels = [solvents.loc[solvents['index'] == idx, 'COSMO_name'].values[0] for idx in solvent_indices_array]
ax.set_yticks(solvent_indices_array)
ax.set_yticklabels(y_labels, rotation=-45, ha='left')

ax.set_xticklabels(ax.get_xticks(), rotation=45, ha='right')  # Rotate x-axis labels for better visibility
ax.tick_params(axis='z', pad=40)  # Increase the padding for y-axis labels
ax.tick_params(axis='y', pad=20)  # Increase the padding for y-axis labels
ax.tick_params(axis='x', pad=20)  # Increase the padding for x-axis labels
#ax.rotate_view = -45  # Set the initial rotation angle
# Add labels and color bar
ax.set_xlabel("Temperature (°C)")
ax.set_ylabel("Solvents")
ax.set_zlabel("Distribution coefficient of Lactic acid")
ax.set_title(f"Distribution coefficient of Lactic Acid vs. Temperature and input mole fraction of lactic acid = {lactic_acid_range[-1]}")

# fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
plt.tight_layout()
# Out:
# C:\Users\kabe02-lokal\AppData\Local\Temp\ipykernel_7972\1956796151.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), rotation=45, ha='right')  # Rotate x-axis labels for better visibility
# C:\Users\kabe02-lokal\AppData\Local\Temp\ipykernel_7972\1956796151.py:36: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# %matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Adjust the figure size to stretch in the y-direction
fig = plt.figure(figsize=(12, 16))  # Increase the height to stretch the plot
ax = fig.add_subplot(111, projection='3d')

# Keep the axis projection as is
# ax.get_proj = lambda: np.dot(Axes3D.get_proj(ax), np.diag([1, 2, 1, 1]))

ax.set_box_aspect([0.25, 1, 0.25])  # Equal aspect ratio for x, y, z

# Plot the surface
surf_1 = ax.plot_surface(X, Y, x_la_org_values[0], cmap='viridis', edgecolor='k', alpha=0.8)
surf_2 = ax.plot_surface(X, Y, x_la_org_values[-1], cmap='viridis', edgecolor='k', alpha=0.8)

# Replace solvent indices with COSMO_name values for y-axis labels
y_labels = [solvents.loc[solvents['index'] == idx, 'COSMO_name'].values[0] for idx in solvent_indices_array]
ax.set_yticks(solvent_indices_array)
ax.set_yticklabels(y_labels, rotation=-45, ha='left')

ax.set_xticklabels(ax.get_xticks(), rotation=45, ha='right')  # Rotate x-axis labels for better visibility
ax.tick_params(axis='z', pad=40)  # Increase the padding for y-axis labels
ax.tick_params(axis='y', pad=20)  # Increase the padding for y-axis labels
ax.tick_params(axis='x', pad=20)  # Increase the padding for x-axis labels
#ax.rotate_view = -45  # Set the initial rotation angle
# Add labels and color bar
ax.set_xlabel("Temperature (°C)")
ax.set_ylabel("Solvents")
ax.set_zlabel("Distribution coefficient of Lactic acid")
ax.set_title(f"Distribution coefficient of Lactic Acid vs. Temperature and input mole fraction of lactic acid = {lactic_acid_range[-1]}")

# fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
plt.tight_layout()
# Out:
# C:\Users\kabe02-lokal\AppData\Local\Temp\ipykernel_7972\3312248031.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticks(), rotation=45, ha='right')  # Rotate x-axis labels for better visibility
# C:\Users\kabe02-lokal\AppData\Local\Temp\ipykernel_7972\3312248031.py:36: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
